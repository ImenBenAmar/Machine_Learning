# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# link of data: https://www.kaggle.com/datasets/uciml/iris

# %%
df=pd.read_csv('/content/Iris.csv',sep=',')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Data Cleaning**

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# **Data visualization**

# %%
df.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
df_corr=df.select_dtypes(include=np.number)
df_corr.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(df_corr.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df,hue='Species')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'])
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
sns.catplot(x='Species',y='SepalLengthCm',data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
plt.subplot(2,2,1)
plt.boxplot(df['SepalLengthCm'])
plt.ylabel('SepalLengthCm')
plt.subplot(2,2,2)
plt.boxplot(df['SepalWidthCm'])
plt.ylabel('SepalWidthCm')
plt.subplot(2,2,3)
plt.boxplot(df['PetalLengthCm'])
plt.ylabel('PetalLengthCm')
plt.subplot(2,2,4)
plt.boxplot(df['PetalWidthCm'])
plt.ylabel('PetalWidthCm')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.catplot(x='SepalLengthCm', y='Species', hue='SepalWidthCm', col='SepalWidthCm', kind='box', data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %% [markdown]
# **DataEncoding**

# %%
x=df.drop('Species',axis=1)
y=df['Species']

# %%
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
x.drop('Id',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import LabelEncoder

# Initialiser LabelEncoder
encoder = LabelEncoder()

# Appliquer l'encodage LabelEncoder
encoded_column = encoder.fit_transform(y)
y_encoded = pd.DataFrame(encoded_column, columns=['Species_encoded']) # Use a descriptive column name

# %%
y_encoded
# Out:
#      Species_encoded
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 145                2
# 146                2
# 147                2
# 148                2
# 149                2
#
# [150 rows x 1 columns]

# %%
print(encoder.classes_)
mapping = dict(zip(encoder.classes_, range(len(encoder.classes_))))
print(mapping)
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y_encoded,test_size=0.2,random_state=42)

# %% [markdown]
# **Modelling**

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test=st.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)
print(y_pred)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
knn.score(x_test,y_test)
# Out:
# 1.0

# %%
y_encoded.head()
# Out:
#    Species_encoded
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
import pandas as pd
# Demander à l'utilisateur de saisir les données
sepal_length = float(input("Entrez la longueur du sépale : "))
sepal_width = float(input("Entrez la largeur du sépale : "))
petal_length = float(input("Entrez la longueur du pétale : "))
petal_width = float(input("Entrez la largeur du pétale : "))

# Créer un DataFrame avec les nouvelles données
# SANS la colonne 'Id' pour correspondre aux données d'entraînement
new_data = pd.DataFrame([[sepal_length, sepal_width, petal_length, petal_width]],
                         columns=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])

# Standardiser les nouvelles données avec le même StandardScaler utilisé pour l'entraînement
new_data_scaled = st.transform(new_data)

# Faire la prédiction avec le modèle KNN
predicted_species = knn.predict(new_data_scaled)

# Afficher la prédiction
print("Espèce prédite :", predicted_species)
# Out:
# Entrez la longueur du sépale : 6
# Entrez la largeur du sépale : 2
# Entrez la longueur du pétale : 4.8
# Entrez la largeur du pétale : 1.6
# Espèce prédite : [1]

# %%
import matplotlib.pyplot as plt
for feature in df.columns[:-1]:
  if feature != 'Id':
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Species', y=feature, data=df)
    plt.title(f'Distribution de {feature} par espèce')
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# **SGD**

# %%
from sklearn.linear_model import SGDClassifier
sgd=SGDClassifier()
sgd.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier()

# %%
y_preds=sgd.predict(x_test)
print(y_preds)
# Out:
# [1 0 2 1 1 0 1 2 2 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
print(sgd.score(x_test,y_test))
# Out:
# 0.9666666666666667

# %%
import pandas as pd
# Demander à l'utilisateur de saisir les données
sepal_length = float(input("Entrez la longueur du sépale : "))
sepal_width = float(input("Entrez la largeur du sépale : "))
petal_length = float(input("Entrez la longueur du pétale : "))
petal_width = float(input("Entrez la largeur du pétale : "))

# Créer un DataFrame avec les nouvelles données
# SANS la colonne 'Id' pour correspondre aux données d'entraînement
new_data = pd.DataFrame([[sepal_length, sepal_width, petal_length, petal_width]],
                         columns=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'])

# Standardiser les nouvelles données avec le même StandardScaler utilisé pour l'entraînement
new_data_scaled = st.transform(new_data)

# Faire la prédiction avec le modèle KNN
predicted_species = sgd.predict(new_data_scaled)

# Afficher la prédiction
print("Espèce prédite :", predicted_species)
# Out:
# Entrez la longueur du sépale : 5
# Entrez la largeur du sépale : 3
# Entrez la longueur du pétale : 2
# Entrez la largeur du pétale : 1
# Espèce prédite : [0]
